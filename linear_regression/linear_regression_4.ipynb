# %%
"""
Linear Regression
Understand how model learns weights and bias
"""
# Out:
# '\nLinear Regression\nUnderstand how model learns weights and bias\n'

# %%
import torch

X = torch.tensor([[2.0], [4.0], [8.0], [10.0]])
y = torch.tensor([[10.0], [16.0], [28.0], [34.0]])

# %%
import torch.nn as nn
learning_rates = [0.01, 0.001, 0.0001]

for lr in learning_rates:
    print(f"\n--- LR: {lr} ---")

    model = nn.Linear(1,1)

    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr = lr)

    for epoch in range(100):
        y_pred = model(X)
        loss = criterion(y_pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print("Final Loss:", loss.item())
    print("Weight:", model.weight.item(), "Bias:", model.bias.item())
# Out:
# --- LR: 0.01 ---
# Final Loss: 1.2258729934692383
# Weight: 3.3098418712615967 Bias: 1.6355829238891602
#
# --- LR: 0.001 ---
# Final Loss: 3.0790324211120605
# Weight: 3.4927725791931152 Bias: 0.23828424513339996
#
# --- LR: 0.0001 ---
# Final Loss: 71.77574157714844
# Weight: 2.271207332611084 Bias: 0.29946479201316833
