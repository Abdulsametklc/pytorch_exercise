# %%
import torch

X = torch.randn(150, 2)
y = 4 * X[:, 0] + 2 * X[:, 1] + 5 +  0.1 * torch.randn(150)
y = y.unsqueeze(1)

# %%
train_size = int(0.8 * len(X))
test_size = len(X) - train_size

X_train = X[:train_size]
y_train = y[:train_size]

X_test = X[train_size:]
y_test = y[train_size:]

# %%
from torch.utils.data import TensorDataset, DataLoader

train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size = 16, shuffle = True)

# %%
import torch.nn as nn 

model = nn.Linear(2,1)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1)

# %%
for epoch in range(100):
    for X_batch, y_batch in train_loader:

        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 0.006744894199073315
# Epoch 2, Loss: 0.0031275481451302767
# Epoch 3, Loss: 0.015883348882198334
# Epoch 4, Loss: 0.01733754202723503
# Epoch 5, Loss: 0.008484410122036934
# Epoch 6, Loss: 0.012725135311484337
# Epoch 7, Loss: 0.013171074911952019
# Epoch 8, Loss: 0.005085085518658161
# Epoch 9, Loss: 0.006359701510518789
# Epoch 10, Loss: 0.02006455510854721
# Epoch 11, Loss: 0.011278092861175537
# Epoch 12, Loss: 0.008455831557512283
# Epoch 13, Loss: 0.006956223864108324
# Epoch 14, Loss: 0.008997003547847271
# Epoch 15, Loss: 0.006300813052803278
# Epoch 16, Loss: 0.005434908904135227
# Epoch 17, Loss: 0.009570012800395489
# Epoch 18, Loss: 0.009250939823687077
# Epoch 19, Loss: 0.004235364496707916
# Epoch 20, Loss: 0.003321246011182666
# Epoch 21, Loss: 0.0020111382473260164
# Epoch 22, Loss: 0.003214400727301836
# Epoch 23, Loss: 0.014894252642989159
# Epoch 24, Loss: 0.01091026607900858
# Epoch 25, Loss: 0.020464282482862473
# Epoch 26, Loss: 0.007464992813766003
# Epoch 27, Loss: 0.004277884028851986
# Epoch 28, Loss: 0.005323878489434719
# Epoch 29, Loss: 0.0024438060354441404
# Epoch 30, Loss: 0.007964000105857849
# Epoch 31, Loss: 0.005178304389119148
# Epoch 32, Loss: 0.0070054070092737675
# Epoch 33, Loss: 0.004210174549371004
# Epoch 34, Loss: 0.008120393380522728
# Epoch 35, Loss: 0.0014620241709053516
# Epoch 36, Loss: 0.007147286552935839
# Epoch 37, Loss: 0.0032352390699088573
# Epoch 38, Loss: 0.0031826940830796957
# Epoch 39, Loss: 0.009370359592139721
# Epoch 40, Loss: 0.0027067477349191904
# Epoch 41, Loss: 0.006203871686011553
# Epoch 42, Loss: 0.004866315983235836
# Epoch 43, Loss: 0.011465632356703281
# Epoch 44, Loss: 0.009488514624536037
# Epoch 45, Loss: 0.007912416942417622
# Epoch 46, Loss: 0.010533338412642479
# Epoch 47, Loss: 0.01326071284711361
# Epoch 48, Loss: 0.005863799713551998
# Epoch 49, Loss: 0.009484927169978619
# Epoch 50, Loss: 0.011097593232989311
# Epoch 51, Loss: 0.004907446913421154
# Epoch 52, Loss: 0.001995027530938387
# Epoch 53, Loss: 0.006367783527821302
# Epoch 54, Loss: 0.00986741203814745
# Epoch 55, Loss: 0.005285930819809437
# Epoch 56, Loss: 0.002738403156399727
# Epoch 57, Loss: 0.008729248307645321
# Epoch 58, Loss: 0.009827477857470512
# Epoch 59, Loss: 0.008125873282551765
# Epoch 60, Loss: 0.011515166610479355
# Epoch 61, Loss: 0.007320575416088104
# Epoch 62, Loss: 0.003624059958383441
# Epoch 63, Loss: 0.0038477692287415266
# Epoch 64, Loss: 0.006466683000326157
# Epoch 65, Loss: 0.007259641773998737
# Epoch 66, Loss: 0.009363045915961266
# Epoch 67, Loss: 0.004039468709379435
# Epoch 68, Loss: 0.00553663307800889
# Epoch 69, Loss: 0.010604463517665863
# Epoch 70, Loss: 0.011218174360692501
# Epoch 71, Loss: 0.005164121277630329
# Epoch 72, Loss: 0.005943875759840012
# Epoch 73, Loss: 0.007590786088258028
# Epoch 74, Loss: 0.008309979923069477
# Epoch 75, Loss: 0.016318321228027344
# Epoch 76, Loss: 0.01685539074242115
# Epoch 77, Loss: 0.0058110738173127174
# Epoch 78, Loss: 0.00941396038979292
# Epoch 79, Loss: 0.004219483584165573
# Epoch 80, Loss: 0.005658755544573069
# Epoch 81, Loss: 0.004837467335164547
# Epoch 82, Loss: 0.008819619193673134
# Epoch 83, Loss: 0.008199470117688179
# Epoch 84, Loss: 0.007516467943787575
# Epoch 85, Loss: 0.006616930477321148
# Epoch 86, Loss: 0.005384902935475111
# Epoch 87, Loss: 0.00945913977921009
# Epoch 88, Loss: 0.0051380363292992115
# Epoch 89, Loss: 0.004430653527379036
# Epoch 90, Loss: 0.004415411967784166
# Epoch 91, Loss: 0.018221158534288406
# Epoch 92, Loss: 0.004867833107709885
# Epoch 93, Loss: 0.00413530133664608
# Epoch 94, Loss: 0.004952990449965
# Epoch 95, Loss: 0.005169675685465336
# Epoch 96, Loss: 0.010301889851689339
# Epoch 97, Loss: 0.007032237946987152
# Epoch 98, Loss: 0.019319524988532066
# Epoch 99, Loss: 0.002248995704576373
# Epoch 100, Loss: 0.0030869951006025076

# %%
with torch.no_grad():
    y_pred = model(X_test)
    test_loss = criterion(y_pred, y_test)

print("Test Loss:", test_loss.item())
# Out:
# Test Loss: 0.009592443704605103
